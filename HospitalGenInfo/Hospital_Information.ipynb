# %% [markdown]
# # Hospital General Information

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/Users/dmj/Jupyter/CGU/IST303/TeamKanto_GroupProject/ist-303-team-kanto-project/HospitalGenInfo/Hospital_General_Information.csv')

# %% [markdown]
# ## EDA

# %%
df.head()
# Out:
#   Facility ID                    Facility Name                     Address  \
# 0      010001  SOUTHEAST HEALTH MEDICAL CENTER      1108 ROSS CLARK CIRCLE
# 1      010005         MARSHALL MEDICAL CENTERS  2505 U S HIGHWAY 431 NORTH
# 2      010006     NORTH ALABAMA MEDICAL CENTER         1701 VETERANS DRIVE
# 3      010007         MIZELL MEMORIAL HOSPITAL               702 N MAIN ST
# 4      010008      CRENSHAW COMMUNITY HOSPITAL         101 HOSPITAL CIRCLE
#
#   City/Town State  ZIP Code County/Parish Telephone Number  \
# 0    DOTHAN    AL     36301       HOUSTON   (334) 793-8701
# 1      BOAZ    AL     35957      MARSHALL   (256) 593-8310
# 2  FLORENCE    AL     35630    LAUDERDALE   (256) 768-8400
# 3       OPP    AL     36467     COVINGTON   (334) 493-3541
# 4   LUVERNE    AL     36049      CRENSHAW   (334) 335-3374
#
#           Hospital Type                           Hospital Ownership  ...  \
# 0  Acute Care Hospitals  Government - Hospital District or Authority  ...
# ...

# %%
df[df['State'] == 'CA'].head()
# Out:
#     Facility ID                                      Facility Name  \
# 315      050002                                   ST ROSE HOSPITAL
# 316      050006                      PROVIDENCE ST JOSEPH HOSPITAL
# 317      050007                           PENINSULA MEDICAL CENTER
# 318      050008  CALIFORNIA PACIFIC MEDICAL CTR-DAVIES CAMPUS HOSP
# 319      050009      PROVIDENCE QUEEN OF THE VALLEY MEDICAL CENTER
#
#                   Address      City/Town State  ZIP Code  County/Parish  \
# 315    27200 CALAROGA AVE        HAYWARD    CA     94545        ALAMEDA
# 316       2700 DOLBEER ST         EUREKA    CA     95501       HUMBOLDT
# 317  1501 TROUSDALE DRIVE     BURLINGAME    CA     94010      SAN MATEO
# 318     601 DUBOCE AVENUE  SAN FRANCISCO    CA     94117  SAN FRANCISCO
# 319       1000 TRANCAS ST           NAPA    CA     94558           NAPA
#
#     Telephone Number         Hospital Type              Hospital Ownership  \
# ...

# %%
df[df['State'] == 'CA']['Hospital Type'].value_counts()
# Out:
# Hospital Type
# Acute Care Hospitals                    277
# Psychiatric                              41
# Critical Access Hospitals                38
# Childrens                                10
# Acute Care - Veterans Administration      8
# Acute Care - Department of Defense        5
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Facility ID',
#  'Facility Name',
#  'Address',
#  'City/Town',
#  'State',
#  'ZIP Code',
#  'County/Parish',
#  'Telephone Number',
#  'Hospital Type',
#  'Hospital Ownership',
#  'Emergency Services',
#  'Meets criteria for birthing friendly designation',
#  'Hospital overall rating',
#  'Hospital overall rating footnote',
#  'MORT Group Measure Count',
#  'Count of Facility MORT Measures',
#  'Count of MORT Measures Better',
#  'Count of MORT Measures No Different',
#  'Count of MORT Measures Worse',
#  'MORT Group Footnote',
#  'Safety Group Measure Count',
#  'Count of Facility Safety Measures',
#  'Count of Safety Measures Better',
#  'Count of Safety Measures No Different',
#  'Count of Safety Measures Worse',
#  'Safety Group Footnote',
#  'READM Group Measure Count',
#  'Count of Facility READM Measures',
#  'Count of READM Measures Better',
#  'Count of READM Measures No Different',
#  'Count of READM Measures Worse',
#  'READM Group Footnote',
# ...

# %% [markdown]
# ##

# %% [markdown]
# ## Filter for LA County Only

# %%
#df[df['County/Parish'].isin(['LOS ANGELES', 'SAN BERNARDINO'])]
df_la = pd.DataFrame(df[df['County/Parish'] == 'LOS ANGELES'])
df_la.reset_index(drop=True, inplace=True)
df_la.head()
# Out:
#   Facility ID                                   Facility Name  \
# 0      050040              LAC/OLIVE VIEW-UCLA MEDICAL CENTER
# 1      050056                        ANTELOPE VALLEY HOSPITAL
# 2      050058             GLENDALE MEM HOSPITAL & HLTH CENTER
# 3      050063           HOLLYWOOD PRESBYTERIAN MEDICAL CENTER
# 4      050078  PROVIDENCE LITTLE CO OF MARY MED CTR SAN PEDRO
#
#                   Address    City/Town State  ZIP Code County/Parish  \
# 0  14445 OLIVE VIEW DRIVE       SYLMAR    CA     91342   LOS ANGELES
# 1            1600 W AVE J    LANCASTER    CA     93534   LOS ANGELES
# 2      1420 S CENTRAL AVE     GLENDALE    CA     91204   LOS ANGELES
# 3      1300 N VERMONT AVE  LOS ANGELES    CA     90027   LOS ANGELES
# 4           1300 W 7TH ST    SAN PEDRO    CA     90732   LOS ANGELES
#
#   Telephone Number         Hospital Type  \
# 0   (818) 364-1555  Acute Care Hospitals
# 1   (661) 949-5500  Acute Care Hospitals
# 2   (818) 502-1900  Acute Care Hospitals
# ...

# %%
df_la.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 38 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Facility ID                                       88 non-null     object
#  1   Facility Name                                     88 non-null     object
#  2   Address                                           88 non-null     object
#  3   City/Town                                         88 non-null     object
#  4   State                                             88 non-null     object
#  5   ZIP Code                                          88 non-null     int64
#  6   County/Parish                                     88 non-null     object
#  7   Telephone Number                                  88 non-null     object
#  8   Hospital Type                                     88 non-null     object
# ...

# %%
df_la['City/Town'].unique()
# Out:
# array(['SYLMAR', 'LANCASTER', 'GLENDALE', 'LOS ANGELES', 'SAN PEDRO',
#        'HUNTINGTON PARK', 'LYNWOOD', 'SANTA MONICA', 'NORTHRIDGE',
#        'VAN NUYS', 'SAN GABRIEL', 'HOLLYWOOD', 'PANORAMA CITY', 'DOWNEY',
#        'ENCINO', 'WHITTIER', 'LONG BEACH', 'PALMDALE', 'POMONA',
#        'BURBANK', 'ARCADIA', 'MISSION HILLS', 'ALHAMBRA', 'MONTEBELLO',
#        'TORRANCE', 'SUN VALLEY', 'COVINA', 'HARBOR CITY', 'PASADENA',
#        'GARDENA', 'WEST HILLS', 'LAKEWOOD', 'SAN DIMAS', 'GLENDORA',
#        'VALENCIA', 'WOODLAND HILLS', 'BALDWIN PARK', 'MONTEREY PARK',
#        'SOUTH EL MONTE', 'INGLEWOOD', 'MARINA DEL REY', 'SHERMAN OAKS',
#        'TARZANA', 'NORWALK', 'AVALON', 'ROSEMEAD', 'CERRITOS', 'RESEDA'],
#       dtype=object)

# %%
len(df_la['City/Town'].unique())
# Out:
# 48

# %%
df_la['Hospital Type'].value_counts()
# Out:
# Hospital Type
# Acute Care Hospitals                    71
# Psychiatric                             12
# Acute Care - Veterans Administration     2
# Childrens                                2
# Critical Access Hospitals                1
# Name: count, dtype: int64

# %%
df_la['Hospital Ownership'].value_counts()
# Out:
# Hospital Ownership
# Proprietary                                    30
# Voluntary non-profit - Private                 28
# Voluntary non-profit - Other                   13
# Voluntary non-profit - Church                   7
# Government - State                              3
# Government - Local                              3
# Veterans Health Administration                  2
# Government - Hospital District or Authority     1
# Physician                                       1
# Name: count, dtype: int64

# %%
df_la['Emergency Services'].value_counts()
# Out:
# Emergency Services
# Yes    53
# No     35
# Name: count, dtype: int64

# %%
df_la['Meets criteria for birthing friendly designation'] = df_la['Meets criteria for birthing friendly designation'].fillna('N')

# %%
df_la['Meets criteria for birthing friendly designation'].value_counts()
# Out:
# Meets criteria for birthing friendly designation
# Y    45
# N    43
# Name: count, dtype: int64

# %%
df_la['Hospital overall rating'].value_counts()
# Out:
# Hospital overall rating
# 3                21
# 2                20
# 4                18
# Not Available    18
# 1                10
# 5                 1
# Name: count, dtype: int64

# %%
df_la['Hospital overall rating'].unique()
# Out:
# array(['2', '1', '3', '4', 'Not Available', '5'], dtype=object)

# %%
df_la['Hospital overall rating'] = df_la['Hospital overall rating'].apply(lambda x: x.replace('Not Available', ''))
#df_la['Hospital overall rating'] = df_la['Hospital overall rating'].apply(lambda x: int(x))

# %% [raw]
# import matplotlib.pyplot as plt
# plt.hist(df_la[df_la['Hospital overall rating'] > 0]['Hospital overall rating'],
#         bins=9)
# plt.title('Distribution of Hospital Overall Ratings')
# plt.show()

# %%
df_la[df_la['Hospital overall rating'] == '5']
# Out:
#    Facility ID                Facility Name            Address    City/Town  \
# 50      050625  CEDARS-SINAI MEDICAL CENTER  8700 BEVERLY BLVD  LOS ANGELES
#
#    State  ZIP Code County/Parish Telephone Number         Hospital Type  \
# 50    CA     90048   LOS ANGELES   (310) 423-5000  Acute Care Hospitals
#
#               Hospital Ownership  ... Count of READM Measures Better  \
# 50  Voluntary non-profit - Other  ...                              2
#
#    Count of READM Measures No Different Count of READM Measures Worse  \
# 50                                    6                             3
#
#     READM Group Footnote Pt Exp Group Measure Count  \
# 50                   NaN                          8
#
#    Count of Facility Pt Exp Measures Pt Exp Group Footnote  \
# 50                                 8                   NaN
#
#    TE Group Measure Count Count of Facility TE Measures  TE Group Footnote
# ...

# %%
df_la[df_la['Hospital overall rating'] == '1']
# Out:
#    Facility ID                            Facility Name  \
# 1       050056                 ANTELOPE VALLEY HOSPITAL
# 35      050376               LAC/HARBOR-UCLA MED CENTER
# 36      050378          PACIFICA HOSPITAL OF THE VALLEY
# 37      050382  EMANATE HEALTH INTER-COMMUNITY HOSPITAL
# 41      050468             MEMORIAL HOSPITAL OF GARDENA
# 47      050588             SAN DIMAS COMMUNITY HOSPITAL
# 55      050704               MISSION COMMUNITY HOSPITAL
# 59      050736                   MONTEREY PARK HOSPITAL
# 60      050737                  GARFIELD MEDICAL CENTER
# 67      050771                     COAST PLAZA HOSPITAL
#
#                        Address      City/Town State  ZIP Code County/Parish  \
# 1                 1600 W AVE J      LANCASTER    CA     93534   LOS ANGELES
# 35            1000 W CARSON ST       TORRANCE    CA     90509   LOS ANGELES
# 36        9449 SAN FERNANDO RD     SUN VALLEY    CA     91352   LOS ANGELES
# ...

# %%
df_la['Hospital overall rating footnote'].value_counts()
# Out:
# Hospital overall rating footnote
# 19.0    14
# 16.0     4
# Name: count, dtype: int64

# %%
df_la['Hospital Ownership'].value_counts()
# Out:
# Hospital Ownership
# Proprietary                                    30
# Voluntary non-profit - Private                 28
# Voluntary non-profit - Other                   13
# Voluntary non-profit - Church                   7
# Government - State                              3
# Government - Local                              3
# Veterans Health Administration                  2
# Government - Hospital District or Authority     1
# Physician                                       1
# Name: count, dtype: int64

# %%
subset = ['Facility ID',
 'Facility Name',
 'Address',
 'City/Town',
 'State',
 'ZIP Code',
 'County/Parish',
 'Telephone Number',
 'Hospital Type',
 'Hospital Ownership',
 'Emergency Services',
 'Meets criteria for birthing friendly designation',
 'Hospital overall rating']

df_subset = pd.DataFrame(df_la[subset])
df_subset.reset_index(drop=True, inplace=True)

# %%
df_subset
# Out:
#    Facility ID                                   Facility Name  \
# 0       050040              LAC/OLIVE VIEW-UCLA MEDICAL CENTER
# 1       050056                        ANTELOPE VALLEY HOSPITAL
# 2       050058             GLENDALE MEM HOSPITAL & HLTH CENTER
# 3       050063           HOLLYWOOD PRESBYTERIAN MEDICAL CENTER
# 4       050078  PROVIDENCE LITTLE CO OF MARY MED CTR SAN PEDRO
# ..         ...                                             ...
# 83      054133    DEPT OF STATE HOSPITALS - METROPOLITAN - PSY
# 84      054147           JOYCE EISENBERG KEEFER MEDICAL CENTER
# 85      054148                        TARZANA TREATMENT CENTER
# 86      054153          OCEAN VIEW PSYCHIATRIC HEALTH FACILITY
# 87      054157                              GLENDORA  HOSPITAL
#
#                            Address    City/Town State  ZIP Code County/Parish  \
# 0           14445 OLIVE VIEW DRIVE       SYLMAR    CA     91342   LOS ANGELES
# ...

# %%
df_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Facility ID                                       88 non-null     object
#  1   Facility Name                                     88 non-null     object
#  2   Address                                           88 non-null     object
#  3   City/Town                                         88 non-null     object
#  4   State                                             88 non-null     object
#  5   ZIP Code                                          88 non-null     int64
#  6   County/Parish                                     88 non-null     object
#  7   Telephone Number                                  88 non-null     object
#  8   Hospital Type                                     88 non-null     object
# ...

# %%
df_subset.head()
# Out:
#   Facility ID                                   Facility Name  \
# 0      050040              LAC/OLIVE VIEW-UCLA MEDICAL CENTER
# 1      050056                        ANTELOPE VALLEY HOSPITAL
# 2      050058             GLENDALE MEM HOSPITAL & HLTH CENTER
# 3      050063           HOLLYWOOD PRESBYTERIAN MEDICAL CENTER
# 4      050078  PROVIDENCE LITTLE CO OF MARY MED CTR SAN PEDRO
#
#                   Address    City/Town State  ZIP Code County/Parish  \
# 0  14445 OLIVE VIEW DRIVE       SYLMAR    CA     91342   LOS ANGELES
# 1            1600 W AVE J    LANCASTER    CA     93534   LOS ANGELES
# 2      1420 S CENTRAL AVE     GLENDALE    CA     91204   LOS ANGELES
# 3      1300 N VERMONT AVE  LOS ANGELES    CA     90027   LOS ANGELES
# 4           1300 W 7TH ST    SAN PEDRO    CA     90732   LOS ANGELES
#
#   Telephone Number         Hospital Type  \
# 0   (818) 364-1555  Acute Care Hospitals
# 1   (661) 949-5500  Acute Care Hospitals
# 2   (818) 502-1900  Acute Care Hospitals
# ...

# %%
print({column:'___' for column in df_subset.columns})
# Out:
# {'Facility ID': '___', 'Facility Name': '___', 'Address': '___', 'City/Town': '___', 'State': '___', 'ZIP Code': '___', 'County/Parish': '___', 'Telephone Number': '___', 'Hospital Type': '___', 'Hospital Ownership': '___', 'Emergency Services': '___', 'Meets criteria for birthing friendly designation': '___', 'Hospital overall rating': '___'}

# %%
df_subset.rename(
    columns={'Facility ID': 'fac_id',
             'Facility Name': 'fac_name',
             'Address': 'address',
             'City/Town': 'city',
             'State': 'state',
             'ZIP Code': 'zip_code',
             'County/Parish': 'county',
             'Telephone Number': 'tel_num',
             'Hospital Type': 'hosp_type',
             'Hospital Ownership': 'hosp_owner',
             'Emergency Services': 'emergency',
             'Meets criteria for birthing friendly designation': 'maternity',
             'Hospital overall rating': 'rating'},
    inplace=True
)

# %%
df_subset['emergency'] = np.where(df_subset['emergency'] == "Yes", 1, 0)
df_subset['maternity'] = np.where(df_subset['maternity'] == "Y", 1, 0)

# %%
df_subset
# Out:
#     fac_id                                        fac_name  \
# 0   050040              LAC/OLIVE VIEW-UCLA MEDICAL CENTER
# 1   050056                        ANTELOPE VALLEY HOSPITAL
# 2   050058             GLENDALE MEM HOSPITAL & HLTH CENTER
# 3   050063           HOLLYWOOD PRESBYTERIAN MEDICAL CENTER
# 4   050078  PROVIDENCE LITTLE CO OF MARY MED CTR SAN PEDRO
# ..     ...                                             ...
# 83  054133    DEPT OF STATE HOSPITALS - METROPOLITAN - PSY
# 84  054147           JOYCE EISENBERG KEEFER MEDICAL CENTER
# 85  054148                        TARZANA TREATMENT CENTER
# 86  054153          OCEAN VIEW PSYCHIATRIC HEALTH FACILITY
# 87  054157                              GLENDORA  HOSPITAL
#
#                            address         city state  zip_code       county  \
# 0           14445 OLIVE VIEW DRIVE       SYLMAR    CA     91342  LOS ANGELES
# 1                     1600 W AVE J    LANCASTER    CA     93534  LOS ANGELES
# ...

# %% [raw]
# df_subset.query('maternity == 1 & emergency == 1 & rating > 3')

# %%
df_subset['urgent_care'] = np.where(df_subset['hosp_type'] == 'Acute Care Hospitals', 1, 0)
df_subset['psychiatric'] = np.where(df_subset['hosp_type'] == 'Psychiatric', 1, 0)
df_subset['childrens'] = np.where(df_subset['hosp_type'] == 'Childrens', 1, 0)
df_subset['veterans'] = np.where(df_subset['hosp_owner'] == 'Veterans Health Administration', 1, 0)
df_subset
# Out:
#     fac_id                                        fac_name  \
# 0   050040              LAC/OLIVE VIEW-UCLA MEDICAL CENTER
# 1   050056                        ANTELOPE VALLEY HOSPITAL
# 2   050058             GLENDALE MEM HOSPITAL & HLTH CENTER
# 3   050063           HOLLYWOOD PRESBYTERIAN MEDICAL CENTER
# 4   050078  PROVIDENCE LITTLE CO OF MARY MED CTR SAN PEDRO
# ..     ...                                             ...
# 83  054133    DEPT OF STATE HOSPITALS - METROPOLITAN - PSY
# 84  054147           JOYCE EISENBERG KEEFER MEDICAL CENTER
# 85  054148                        TARZANA TREATMENT CENTER
# 86  054153          OCEAN VIEW PSYCHIATRIC HEALTH FACILITY
# 87  054157                              GLENDORA  HOSPITAL
#
#                            address         city state  zip_code       county  \
# 0           14445 OLIVE VIEW DRIVE       SYLMAR    CA     91342  LOS ANGELES
# 1                     1600 W AVE J    LANCASTER    CA     93534  LOS ANGELES
# ...

# %%
df_subset['maternity'].value_counts()
# Out:
# maternity
# 1    45
# 0    43
# Name: count, dtype: int64

# %%
df_subset['emergency'].value_counts()
# Out:
# emergency
# 1    53
# 0    35
# Name: count, dtype: int64

# %%
df_subset['veterans'].value_counts()
# Out:
# veterans
# 0    86
# 1     2
# Name: count, dtype: int64

# %%
df_subset['childrens'].value_counts()
# Out:
# childrens
# 0    86
# 1     2
# Name: count, dtype: int64

# %%
df_subset.to_csv('LACOUNTY.csv')

# %%
import os
if os.path.exists('test_database.db') == False:

    table_name = 'lacounty'
    
    conn = 'sqlite:///test_database.db'
    
    df_subset.to_sql(table_name, conn, if_exists='append', index=False)
else: 
    print('Table Already Exists')
# Out:
# Table Already Exists
