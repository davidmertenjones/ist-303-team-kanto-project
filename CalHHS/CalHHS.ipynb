# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('/Users/dmj/Jupyter/CGU/IST303/TeamKanto_GroupProject/ist-303-team-kanto-project/CalHHS/current-healthcare-facility-listing.csv')

# %%
df_la1 = pd.DataFrame(df1[df1['COUNTY_NAME'] == 'Los Angeles'])
df_la1.reset_index(drop=True, inplace=True)
df_la1
# Out:
#        OSHPD_ID  PERM_ID                                   FACILITY_NAME  \
# 0     106190017  11386.0                ALHAMBRA HOSPITAL MEDICAL CENTER
# 1     106190020  11388.0                           BHC ALHAMBRA HOSPITAL
# 2     106190021      NaN  TELECARE MLK ADULT PSYCHIATRIC HEALTH FACILITY
# 3     106190034  11399.0                  ANTELOPE VALLEY MEDICAL CENTER
# 4     106190040      NaN                 BEST CARE UNLIMITED HOME HEALTH
# ...         ...      ...                                             ...
# 5911  406564172      NaN             GIBRALTAR HOME HEALTH SERVICES, LLC
# 5912  406564227      NaN                                CARE ONE HOSPICE
# 5913  406564263      NaN  HESTIA HOSPICE AND PALLIATIVE CARE CORPORATION
# 5914  406564288      NaN                        VEROMA HOME HEALTH, INC.
# 5915  406567401      NaN            YOUR HEALTH, OUR PRIORITYHOME HEALTH
#
#      LICENSE_NUM          FACILITY_LEVEL_DESC                   DBA_ADDRESS1  \
# ...

# %%
df_la1.columns.tolist()
# Out:
# ['OSHPD_ID',
#  'PERM_ID',
#  'FACILITY_NAME',
#  'LICENSE_NUM',
#  'FACILITY_LEVEL_DESC',
#  'DBA_ADDRESS1',
#  'DBA_CITY',
#  'DBA_ZIP_CODE',
#  'COUNTY_CODE',
#  'COUNTY_NAME',
#  'ER_SERVICE_LEVEL_DESC',
#  'TOTAL_NUMBER_BEDS',
#  'FACILITY_STATUS_DESC',
#  'FACILITY_STATUS_DATE',
#  'LICENSE_TYPE_DESC',
#  'LICENSE_CATEGORY_DESC',
#  'LATITUDE',
#  'LONGITUDE']

# %%
df_la1['ER_SERVICE_LEVEL_DESC'].value_counts()
# Out:
# ER_SERVICE_LEVEL_DESC
# Not Applicable               5816
# Emergency - Basic              68
# Emergency - Standby             2
# Emergency - Comprehensive       2
# Name: count, dtype: int64

# %%
df_la1['FACILITY_LEVEL_DESC'].value_counts()
# Out:
# FACILITY_LEVEL_DESC
# Home Health Agency                   2946
# Hospice                              1794
# Skilled Nursing Facility              348
# Community Clinic                      341
# Chronic Dialysis Clinic               197
# Congregate Living Health Facility     143
# General Acute Care Hospital           100
# Acute Psychiatric Hospital             13
# Psychology Clinic                       7
# Free Clinic                             6
# Psychiatric Health Facility             5
# Surgical Clinic                         5
# Rehabilitation Clinic                   5
# ICF/Dev. Disabled                       4
# Chemical Dep. Recovery Hospital         2
# Name: count, dtype: int64

# %%
df_la1['LICENSE_CATEGORY_DESC'].value_counts()
# Out:
# LICENSE_CATEGORY_DESC
# Home Health Agency                   2946
# Hospice                              1794
# Skilled Nursing Facility              348
# Community Clinic                      341
# Chronic Dialysis Clinic               197
# Congregate Living Health Facility     143
# General Acute Care Hospital           100
# Acute Psychiatric Hospital             13
# Psychology Clinic                       7
# Free Clinic                             6
# Psychiatric Health Facility             5
# Surgical Clinic                         5
# Rehabilitation Clinic                   5
# ICF/Dev. Disabled                       4
# Chemical Dep. Recovery Hospital         2
# Name: count, dtype: int64

# %%
df_la1['LICENSE_CATEGORY_DESC'].value_counts()
# Out:
# LICENSE_CATEGORY_DESC
# Home Health Agency                   2946
# Hospice                              1794
# Skilled Nursing Facility              348
# Community Clinic                      341
# Chronic Dialysis Clinic               197
# Congregate Living Health Facility     143
# General Acute Care Hospital           100
# Acute Psychiatric Hospital             13
# Psychology Clinic                       7
# Free Clinic                             6
# Psychiatric Health Facility             5
# Surgical Clinic                         5
# Rehabilitation Clinic                   5
# ICF/Dev. Disabled                       4
# Chemical Dep. Recovery Hospital         2
# Name: count, dtype: int64
